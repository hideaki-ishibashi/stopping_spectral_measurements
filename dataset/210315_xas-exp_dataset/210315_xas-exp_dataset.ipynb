# %%
import os
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# '/Users/tetsuro/Desktop/20210314_Ueno'

# %%
data = pd.read_csv("MnO2_1", header=7, names=["Target","Energy","Time","Ch0","Ch1","Ch2","Ch3","Ch4","Ch5","Ch6","Ch7","Ch4_corr",])
plt.plot(data.Energy,data.Ch3/data.Ch2)
plt.xlabel("Photon energy (eV)")
plt.ylabel("Intensity (arb. units")
plt.title("MnO2_1")
plt.show()

# %%
data = pd.read_csv("MnO2_4", header=7, names=["Target","Energy","Time","Ch0","Ch1","Ch2","Ch3","Ch4","Ch5","Ch6","Ch7","Ch4_corr",])
plt.plot(data.Energy,data.Ch3/data.Ch2)
plt.xlabel("Photon energy (eV)")
plt.ylabel("Intensity (arb. units")
plt.title("MnO2_4")
plt.show()

# %%
data = pd.read_csv("MnO2_7", header=7, names=["Target","Energy","Time","Ch0","Ch1","Ch2","Ch3","Ch4","Ch5","Ch6","Ch7","Ch4_corr",])
plt.plot(data.Energy,data.Ch3/data.Ch2)
plt.xlabel("Photon energy (eV)")
plt.ylabel("Intensity (arb. units")
plt.title("MnO2_7")
plt.show()

# %%
data = pd.read_csv("Co_2", header=7, names=["Target","Energy","Time","Ch0","Ch1","Ch2","Ch3","Ch4","Ch5","Ch6","Ch7","Ch4_corr",])
plt.plot(data.Energy,data.Ch3/data.Ch2)
plt.xlabel("Photon energy (eV)")
plt.ylabel("Intensity (arb. units")
plt.title("Co_2")
plt.show()

# %%
data = pd.read_csv("Co_3", header=7, names=["Target","Energy","Time","Ch0","Ch1","Ch2","Ch3","Ch4","Ch5","Ch6","Ch7","Ch4_corr",])
plt.plot(data.Energy,data.Ch3/data.Ch2)
plt.xlabel("Photon energy (eV)")
plt.ylabel("Intensity (arb. units")
plt.title("Co_3")
plt.show()

# %%
data = pd.read_csv("Co_5", header=7, names=["Target","Energy","Time","Ch0","Ch1","Ch2","Ch3","Ch4","Ch5","Ch6","Ch7","Ch4_corr",])
plt.plot(data.Energy,data.Ch3/data.Ch2)
plt.xlabel("Photon energy (eV)")
plt.ylabel("Intensity (arb. units")
plt.title("Co_5")
plt.show()

# %%
data = pd.read_csv("Ni_3", header=7, names=["Target","Energy","Time","Ch0","Ch1","Ch2","Ch3","Ch4","Ch5","Ch6","Ch7","Ch4_corr",])
plt.plot(data.Energy,data.Ch3/data.Ch2)
plt.xlabel("Photon energy (eV)")
plt.ylabel("Intensity (arb. units")
plt.title("Ni_3")
plt.show()

# %%
data = pd.read_csv("Ni_4", header=7, names=["Target","Energy","Time","Ch0","Ch1","Ch2","Ch3","Ch4","Ch5","Ch6","Ch7","Ch4_corr",])
plt.plot(data.Energy,data.Ch3/data.Ch2)
plt.xlabel("Photon energy (eV)")
plt.ylabel("Intensity (arb. units")
plt.title("Ni_4")
plt.show()

# %%
data = pd.read_csv("Ni_6", header=7, names=["Target","Energy","Time","Ch0","Ch1","Ch2","Ch3","Ch4","Ch5","Ch6","Ch7","Ch4_corr",])
plt.plot(data.Energy,data.Ch3/data.Ch2)
plt.xlabel("Photon energy (eV)")
plt.ylabel("Intensity (arb. units")
plt.title("Ni_6")
plt.show()
